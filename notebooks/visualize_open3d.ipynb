# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# 🟢 Visualize 3D Point Cloud (Open3D)\n",
#     "This notebook loads a local or S3 point cloud and visualizes it using Open3D."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import open3d as o3d\n",
#     "import numpy as np\n",
#     "import boto3\n",
#     "import tempfile"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 🔹 Option 1 — Load and visualize *local* PLY"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "pcd = o3d.io.read_point_cloud('../data/bunny.ply')\n",
#     "o3d.visualization.draw_geometries([pcd])"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 🔹 Option 2 — Load point cloud *from S3*"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "bucket = \"your-bucket-name\"  # change this\n",
#     "key = \"raw/bunny.ply\""
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 4,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "s3 = boto3.client('s3')\n",
#     "with tempfile.NamedTemporaryFile(suffix='.ply') as tmp:\n",
#     "    s3.download_file(bucket, key, tmp.name)\n",
#     "    pcd_s3 = o3d.io.read_point_cloud(tmp.name)\n",
#     "    o3d.visualization.draw_geometries([pcd_s3])"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.10"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
